# %% [markdown]
# # Section 2
# In this section of tutorial, you will:
# 1. Load an unlabeled dataset
# 2. Examine the distribution of classifier scores
# 3. Select a data sample for getting the oracle labels (e.g., send for human annotation)
# 4. Select a data sample by two different ways: random, uniform on C(X)
#     * Construct three representations of the joint distribution for the data sample generated by different sampling stratgy
#     * Obtain a calibration curve from the labeled data sample in two ways: Nonparametric binning and Platt scaling
#     * Estimate the prevalence of the original unlabeled dataset using a calibration curve learned from the labeled data sample
#     * Generating confidence interval estimation by bootstrapping the labeled data sample
#
# For the exercises, we ask you to rerun this code on a different dataset and answer the following questions:
# 1. What’s the method call to get the ground truth labels?
# 2. With 5000 labels randomly sampled…
#     * What is the fraction of ground truth positive in the sample?
#     * What is the estimated fraction of ground truth positive for the whole 100K?
#     * What is the actual fraction of ground truth positive labels for the whole 100K?
#     * How close are these to each other and why are they not exactly the same?
#     * How big is the 95% confidence interval around estimated GT?
# 3. With 5000 labels uniformly sampled according to C(X)...
#     * What is the fraction of ground truth positive in the sample?
#     * What is the estimated fraction of ground truth positive for the whole 100K?
#     * What is the actual fraction of ground truth positive labels for the whole 100K?
#     * How close are these to each other and why are they not exactly the same?
#     * How big is the 95% confidence interval around estimated GT?
# 4. Looking at the grid of results representation, what are key differences between random sampling and uniform sampling?
# 5. Fill in columns D and E rows 6-13
#
# You should also fill in column E and F for dataset 2 in your copy of the [results spreadsheet]( https://docs.google.com/spreadsheets/d/10oEQR-_6px9sRF3cRiIPChiBcrWPVPy12TN7oHCA4qU), based on your findings from the notebook.

# %%
import sys
from os.path import dirname, abspath

sys.path.append(dirname(abspath('')))

# %%
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

from calibration_extrapolation.util import plot_stacked_frequency
from calibration_extrapolation.data_handler import DataHandler
from calibration_extrapolation.calibration_curve import LogisticCalibrationCurve, NPBinningCalibrationCurve
from calibration_extrapolation.extrinsic_estimator import ProbabilityEstimator

# %% [markdown]
# ## 1. Load an unlabeled dataset

# %%
# base is a very large dataset
base_dh = DataHandler('../data/dataset1_base.csv')

# %%
# TODO: change the dataset to 'data/dataset1_target.csv'
# base_dh = DataHandler('data/dataset1_target.csv')

# %%
# you observe only classifier scores C(X), but no GT labels
base_dh.observed_df
# Out:
#            C(X) GT
# 0      0.254796
# 1      0.888630
# 2      0.815468
# 3      0.801820
# 4      0.209585
# ...         ... ..
# 99995  0.383462
# 99996  0.937050
# 99997  0.066808
# 99998  0.358555
# 99999  0.079117
#
# [100000 rows x 2 columns]

# %%
# count_gt() function returns the number of items with GT labels
base_dh.count_gt()
# Out:
# 0

# %% [markdown]
# ## 2. distribution of classifier scores

# %%
base_dh.plot_dist_classifier_scores()

# %% [markdown]
# ## 3. Assume that we have some budget to obtain the GT labels

# %%
# the `get_oracle_labels` function will get the GT labels for specifc rows
base_dh.get_oracle_labels(rows=[0, 1, 2])

# %%
base_dh.observed_df
# Out:
#            C(X)     GT
# 0      0.254796  False
# 1      0.888630   True
# 2      0.815468   True
# 3      0.801820
# 4      0.209585
# ...         ...    ...
# 99995  0.383462
# 99996  0.937050
# 99997  0.066808
# 99998  0.358555
# 99999  0.079117
#
# [100000 rows x 2 columns]

# %%
# we can also get a subset of all labeled rows
base_dh.sample_df
# Out:
#        C(X)     GT
# 0  0.254796  False
# 1  0.888630   True
# 2  0.815468   True

# %% [markdown]
# ## 4. Different ways of sampling and distribution profiles: Random sampling

# %%
base_dh.hide_all_oracle()

# %%
sampeld_rows = base_dh.get_sample_for_labeling(n_item=5000, strategy='random')

# %%
base_dh.get_oracle_labels(rows=sampeld_rows)

# %%
base_dh.count_gt()
# Out:
# 5000

# %%
base_dh.sample_df
# Out:
#            C(X)     GT
# 16     0.171813  False
# 21     0.263270  False
# 48     0.894809   True
# 54     0.526202  False
# 69     0.758395   True
# ...         ...    ...
# 99961  0.807961   True
# 99963  0.283601  False
# 99965  0.367496  False
# 99968  0.184445  False
# 99988  0.458328  False
#
# [5000 rows x 2 columns]

# %%
random_sample_df = base_dh.sample_df

# %%
random_sample_df.shape
# Out:
# (5000, 2)

# %% [markdown]
# ### 4.1. Joint Distributions of the Random Labeled Sample

# %%
base_dh.generate_all_distribution_plots(df=random_sample_df, num_bin=10)

# %% [markdown]
# ### 4.2 Obtain a Calibration Curve

# %% [markdown]
# #### 4.2.1. Nonparametric binning calibration curve

# %%
sample_calibration_curve = NPBinningCalibrationCurve(random_sample_df, num_bin=10)

# %%
sample_calibration_curve.plot()

# %% [markdown]
# #### 4.2.1. Logistic regression calibration curve

# %%
sample_calibration_curve = LogisticCalibrationCurve()
sample_calibration_curve.fit(random_sample_df)

# %%
sample_calibration_curve.plot()

# %% [markdown]
# ### 4.3 Estimate the prevalence of the original unlabeled dataset using a calibration curve learned from the labeled data sample

# %% [markdown]
# #### 4.3.1. With a Nonparametric binning calibration curve

# %%
pe_estimator = ProbabilityEstimator()

sample_calibration_curve = NPBinningCalibrationCurve(random_sample_df, num_bin=10)
pe_estimator.set_calibration_curve(sample_calibration_curve)

input_cx_array = base_dh.observed_df['C(X)'].values

pe_estimator.estimate(input_cx_array)
# Out:
# 0.19830907767474729

# %% [markdown]
# #### 4.3.2 With a LogisticCalibrationCurve

# %%
pe_estimator = ProbabilityEstimator()

sample_calibration_curve = LogisticCalibrationCurve()
sample_calibration_curve.fit(random_sample_df)
pe_estimator.set_calibration_curve(sample_calibration_curve)

input_cx_array = base_dh.observed_df['C(X)'].values

pe_estimator.estimate(input_cx_array)
# Out:
# 0.19789596294894993

# %% [markdown]
# ### 4.4 Obtaining confidence intervals by Bootstrap sampling the labeled sample

# %%
def bootstrap_estimating(input_cx_array, df, num_bootstrap, calibration_curve='platt scaling', verbose=False):
    pe_estimator = ProbabilityEstimator()

    estimated_result_list = []

    for bootstrap_idx in range(num_bootstrap):
        n_item = len(df)
        bootstrapped_sample_df = df.sample(frac=1, replace=True)

        if calibration_curve == 'platt scaling':
            bootstrapped_calibration_curve = LogisticCalibrationCurve()
            bootstrapped_calibration_curve.fit(bootstrapped_sample_df)
        elif calibration_curve == 'nonparametric binning':
            bootstrapped_calibration_curve = NPBinningCalibrationCurve(bootstrapped_sample_df, num_bin=10)

        pe_estimator.set_calibration_curve(bootstrapped_calibration_curve)

        bootstrapped_pe_estimation = pe_estimator.estimate(input_cx_array)
        if verbose:
            print(f'bootstrap {bootstrap_idx+1:>3}: {bootstrapped_pe_estimation:.4f}')
        estimated_result_list.append(bootstrapped_pe_estimation)    
    return estimated_result_list

# %% [markdown]
# #### 4.4.1 Use random sample to make estimation with PE estimator

# %%
npbin_estimated_result_list = bootstrap_estimating(base_dh.observed_df['C(X)'].values, 
                                                   random_sample_df, 
                                                   num_bootstrap=500, 
                                                   calibration_curve='nonparametric binning', 
                                                   verbose=True)
# Out:
# bootstrap   1: 0.1973
# bootstrap   2: 0.1989
# bootstrap   3: 0.1989
# bootstrap   4: 0.1952
# bootstrap   5: 0.1983
# bootstrap   6: 0.1951
# bootstrap   7: 0.1991
# bootstrap   8: 0.1988
# bootstrap   9: 0.1994
# bootstrap  10: 0.1969
# bootstrap  11: 0.1966
# bootstrap  12: 0.1990
# bootstrap  13: 0.1932
# bootstrap  14: 0.1993
# bootstrap  15: 0.1985
# bootstrap  16: 0.1993
# bootstrap  17: 0.2035
# bootstrap  18: 0.1996
# bootstrap  19: 0.2014
# bootstrap  20: 0.2005
# bootstrap  21: 0.1991
# bootstrap  22: 0.1993
# bootstrap  23: 0.1973
# bootstrap  24: 0.1957
# bootstrap  25: 0.1962
# bootstrap  26: 0.2009
# bootstrap  27: 0.1936
# bootstrap  28: 0.2027
# bootstrap  29: 0.1978
# bootstrap  30: 0.1990
# bootstrap  31: 0.2022
# bootstrap  32: 0.2000
# bootstrap  33: 0.2003
# bootstrap  34: 0.2001
# bootstrap  35: 0.1979
# bootstrap  36: 0.1981
# bootstrap  37: 0.1934
# bootstrap  38: 0.1986
# bootstrap  39: 0.1992
# bootstrap  40: 0.2004
# bootstrap  41: 0.1993
# bootstrap  42: 0.1973
# bootstrap  43: 0.2022
# bootstrap  44: 0.2003
# bootstrap  45: 0.1951
# bootstrap  46: 0.1945
# bootstrap  47: 0.1974
# bootstrap  48: 0.1990
# bootstrap  49: 0.1949
# bootstrap  50: 0.1999
# bootstrap  51: 0.1970
# bootstrap  52: 0.1995
# bootstrap  53: 0.1996
# bootstrap  54: 0.1994
# bootstrap  55: 0.1981
# bootstrap  56: 0.1984
# bootstrap  57: 0.2010
# bootstrap  58: 0.1975
# bootstrap  59: 0.1994
# bootstrap  60: 0.1958
# bootstrap  61: 0.1966
# bootstrap  62: 0.1976
# bootstrap  63: 0.1998
# bootstrap  64: 0.1994
# bootstrap  65: 0.1991
# bootstrap  66: 0.1992
# bootstrap  67: 0.1980
# bootstrap  68: 0.1970
# bootstrap  69: 0.1988
# bootstrap  70: 0.2013
# bootstrap  71: 0.1965
# bootstrap  72: 0.1976
# bootstrap  73: 0.1973
# bootstrap  74: 0.2011
# bootstrap 477: 0.1970
# bootstrap 478: 0.1969
# bootstrap 479: 0.1972
# bootstrap 480: 0.1938
# bootstrap 481: 0.1931
# bootstrap 482: 0.1987
# bootstrap 483: 0.1989
# bootstrap 484: 0.2001
# bootstrap 485: 0.2007
# bootstrap 486: 0.1938
# bootstrap 487: 0.1981
# bootstrap 488: 0.2004
# bootstrap 489: 0.1938
# bootstrap 490: 0.1964
# bootstrap 491: 0.1941
# bootstrap 492: 0.1930
# bootstrap 493: 0.1953
# bootstrap 494: 0.1973
# bootstrap 495: 0.1978
# bootstrap 496: 0.1975
# bootstrap 497: 0.2019
# bootstrap 498: 0.1997
# bootstrap 499: 0.1942
# bootstrap 500: 0.1968

# %%
def get_median_CI(lst):
    return f'Median estimation is {np.median(lst):.3f}, CI95 is ({np.percentile(lst, 2.5):.3f}, {np.percentile(lst, 97.5):.3f})'

# %%
get_median_CI(npbin_estimated_result_list)
# Out:
# 'Median estimation is 0.199, CI95 is (0.194, 0.203)'

# %% [markdown]
# #### 4.4.1 Use purposive sample to make estimation with PE estimator

# %%
ps_estimated_result_list = bootstrap_estimating(base_dh.observed_df['C(X)'].values, 
                                                random_sample_df, 
                                                num_bootstrap=500, 
                                                calibration_curve='platt scaling', 
                                                verbose=True)
# Out:
# bootstrap   1: 0.1973
# bootstrap   2: 0.1953
# bootstrap   3: 0.1984
# bootstrap   4: 0.2002
# bootstrap   5: 0.2005
# bootstrap   6: 0.1962
# bootstrap   7: 0.1984
# bootstrap   8: 0.1949
# bootstrap   9: 0.1990
# bootstrap  10: 0.1987
# bootstrap  11: 0.2000
# bootstrap  12: 0.1994
# bootstrap  13: 0.1955
# bootstrap  14: 0.1969
# bootstrap  15: 0.2004
# bootstrap  16: 0.1998
# bootstrap  17: 0.1968
# bootstrap  18: 0.1975
# bootstrap  19: 0.1984
# bootstrap  20: 0.1994
# bootstrap  21: 0.1977
# bootstrap  22: 0.1943
# bootstrap  23: 0.1973
# bootstrap  24: 0.1980
# bootstrap  25: 0.2003
# bootstrap  26: 0.1983
# bootstrap  27: 0.1972
# bootstrap  28: 0.1985
# bootstrap  29: 0.2000
# bootstrap  30: 0.1955
# bootstrap  31: 0.1981
# bootstrap  32: 0.1988
# bootstrap  33: 0.1988
# bootstrap  34: 0.1952
# bootstrap  35: 0.1983
# bootstrap  36: 0.1975
# bootstrap  37: 0.2030
# bootstrap  38: 0.1936
# bootstrap  39: 0.1996
# bootstrap  40: 0.2029
# bootstrap  41: 0.1973
# bootstrap  42: 0.1983
# bootstrap  43: 0.2009
# bootstrap  44: 0.1966
# bootstrap  45: 0.1985
# bootstrap  46: 0.1973
# bootstrap  47: 0.2004
# bootstrap  48: 0.1965
# bootstrap  49: 0.1981
# bootstrap  50: 0.1958
# bootstrap  51: 0.2003
# bootstrap  52: 0.1957
# bootstrap  53: 0.1983
# bootstrap  54: 0.1959
# bootstrap  55: 0.2000
# bootstrap  56: 0.1966
# bootstrap  57: 0.1998
# bootstrap 461: 0.1980
# bootstrap 462: 0.1972
# bootstrap 463: 0.2002
# bootstrap 464: 0.1987
# bootstrap 465: 0.2012
# bootstrap 466: 0.1994
# bootstrap 467: 0.1984
# bootstrap 468: 0.1982
# bootstrap 469: 0.1996
# bootstrap 470: 0.2008
# bootstrap 471: 0.2001
# bootstrap 472: 0.1981
# bootstrap 473: 0.1941
# bootstrap 474: 0.1950
# bootstrap 475: 0.1992
# bootstrap 476: 0.1973
# bootstrap 477: 0.1961
# bootstrap 478: 0.1980
# bootstrap 479: 0.1975
# bootstrap 480: 0.1978
# bootstrap 481: 0.1948
# bootstrap 482: 0.1996
# bootstrap 483: 0.1985
# bootstrap 484: 0.1949
# bootstrap 485: 0.1986
# bootstrap 486: 0.2017
# bootstrap 487: 0.1935
# bootstrap 488: 0.1998
# bootstrap 489: 0.2000
# bootstrap 490: 0.1937
# bootstrap 491: 0.1979
# bootstrap 492: 0.1963
# bootstrap 493: 0.1957
# bootstrap 494: 0.1970
# bootstrap 495: 0.1963
# bootstrap 496: 0.2014
# bootstrap 497: 0.1971
# bootstrap 498: 0.1975
# bootstrap 499: 0.1966
# bootstrap 500: 0.1986

# %%
get_median_CI(ps_estimated_result_list)
# Out:
# 'Median estimation is 0.198, CI95 is (0.194, 0.202)'

# %% [markdown]
# ## But random sampling is often undesired for the highly imbalanced social media data, so we switch to uniform sampling on C(X)

# %% [markdown]
# ### 2.2 Uniform sampling on C(X)
#
# check if uniform will give us a tighter confidence intervals

# %%
base_dh.hide_all_oracle()

# %%
base_dh.count_gt()
# Out:
# 0

# %%
sampeld_rows = base_dh.get_sample_for_labeling(n_item=5000, strategy='uniform on C(X)')
# sampeld_rows = base_dh.get_sample_for_labeling(n_item=1000, strategy='neyman')

# %%
base_dh.get_oracle_labels(rows=sampeld_rows)

# %%
base_dh.count_gt()
# Out:
# 5000

# %%
base_dh.sample_df
# Out:
#            C(X)     GT
# 0      0.254796  False
# 1      0.888630   True
# 2      0.815468   True
# 3      0.801820   True
# 4      0.209585  False
# ...         ...    ...
# 13215  0.677874  False
# 13221  0.617350   True
# 13228  0.663543  False
# 13246  0.653422  False
# 13247  0.628898  False
#
# [5000 rows x 2 columns]

# %%
purposive_sample_df = base_dh.sample_df

# %%
base_dh.generate_all_distribution_plots(df=purposive_sample_df, num_bin=10)

# %%
base_dh.generate_all_distribution_plots(df=random_sample_df, num_bin=10)

# %% [markdown]
# ### What if we use a different sampling strategy?

# %%
npbin_estimated_result_list = bootstrap_estimating(base_dh.observed_df['C(X)'].values,
                                                   purposive_sample_df, 
                                                   num_bootstrap=500, 
                                                   calibration_curve='nonparametric binning', 
                                                   verbose=True)
# Out:
# bootstrap   1: 0.2015
# bootstrap   2: 0.2026
# bootstrap   3: 0.2005
# bootstrap   4: 0.1997
# bootstrap   5: 0.2036
# bootstrap   6: 0.2055
# bootstrap   7: 0.2045
# bootstrap   8: 0.2006
# bootstrap   9: 0.2027
# bootstrap 413: 0.1998
# bootstrap 414: 0.2052
# bootstrap 415: 0.2005
# bootstrap 416: 0.1989
# bootstrap 417: 0.2018
# bootstrap 418: 0.2012
# bootstrap 419: 0.2019
# bootstrap 420: 0.2017
# bootstrap 421: 0.2001
# bootstrap 422: 0.2011
# bootstrap 423: 0.2007
# bootstrap 424: 0.2014
# bootstrap 425: 0.2003
# bootstrap 426: 0.2009
# bootstrap 427: 0.2021
# bootstrap 428: 0.1997
# bootstrap 429: 0.2035
# bootstrap 430: 0.2029
# bootstrap 431: 0.2007
# bootstrap 432: 0.2025
# bootstrap 433: 0.2002
# bootstrap 434: 0.2009
# bootstrap 435: 0.2023
# bootstrap 436: 0.1973
# bootstrap 437: 0.2019
# bootstrap 438: 0.2007
# bootstrap 439: 0.2007
# bootstrap 440: 0.2001
# bootstrap 441: 0.2028
# bootstrap 442: 0.1997
# bootstrap 443: 0.2013
# bootstrap 444: 0.2039
# bootstrap 445: 0.2006
# bootstrap 446: 0.2004
# bootstrap 447: 0.2016
# bootstrap 448: 0.2021
# bootstrap 449: 0.2048
# bootstrap 450: 0.2008
# bootstrap 451: 0.2014
# bootstrap 452: 0.2019
# bootstrap 453: 0.1998
# bootstrap 454: 0.2017
# bootstrap 455: 0.2035
# bootstrap 456: 0.2012
# bootstrap 457: 0.1983
# bootstrap 458: 0.2013
# bootstrap 459: 0.2008
# bootstrap 460: 0.2007
# bootstrap 461: 0.2043
# bootstrap 462: 0.2051
# bootstrap 463: 0.2020
# bootstrap 464: 0.2023
# bootstrap 465: 0.2029
# bootstrap 466: 0.2034
# bootstrap 467: 0.2025
# bootstrap 468: 0.1997
# bootstrap 469: 0.2017
# bootstrap 470: 0.2032
# bootstrap 471: 0.2035
# bootstrap 472: 0.2016
# bootstrap 473: 0.2030
# bootstrap 474: 0.2006
# bootstrap 475: 0.2002
# bootstrap 476: 0.1979
# bootstrap 477: 0.2009
# bootstrap 478: 0.2041
# bootstrap 479: 0.2019
# bootstrap 480: 0.2030
# bootstrap 481: 0.2020
# bootstrap 482: 0.2021
# bootstrap 483: 0.2043
# bootstrap 484: 0.1984
# bootstrap 485: 0.2018
# bootstrap 486: 0.2027
# bootstrap 487: 0.1997
# bootstrap 488: 0.2017
# bootstrap 489: 0.2020
# bootstrap 490: 0.2008
# bootstrap 491: 0.2033
# bootstrap 492: 0.1980
# bootstrap 493: 0.2022
# bootstrap 494: 0.2025
# bootstrap 495: 0.2041
# bootstrap 496: 0.1996
# bootstrap 497: 0.2031
# bootstrap 498: 0.2002
# bootstrap 499: 0.2008
# bootstrap 500: 0.2037

# %%
get_median_CI(npbin_estimated_result_list)
# Out:
# 'Median estimation is 0.202, CI95 is (0.198, 0.205)'

# %%
ps_estimated_result_list = bootstrap_estimating(base_dh.observed_df['C(X)'].values,
                                                purposive_sample_df, 
                                                num_bootstrap=500, 
                                                calibration_curve='platt scaling', 
                                                verbose=True)
# Out:
# bootstrap   1: 0.2063
