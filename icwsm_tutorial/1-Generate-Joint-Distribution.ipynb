# %%
import sys
from os.path import dirname, abspath

sys.path.append(dirname(abspath('')))

# %%
import pandas as pd

example_df1 = pd.read_csv('data/example_data1.csv')

# %%
example_df1.head()
# Out:
#        C(X) gt_label
# 0  0.368554      pos
# 1  0.900048      pos
# 2  0.742137      pos
# 3  0.754380      pos
# 4  0.965738      pos

# %%
example_df1.rename(columns={'C(X)': 'pos'}, inplace=True)

# %%
example_df1['neg'] = 1 - example_df1['pos']

# %%
example_df1.head()
# Out:
#         pos gt_label       neg
# 0  0.368554      pos  0.631446
# 1  0.900048      pos  0.099952
# 2  0.742137      pos  0.257863
# 3  0.754380      pos  0.245620
# 4  0.965738      pos  0.034262

# %%
from pyquantifier.data import Dataset

# %%
example_dataset1_dataset = Dataset(df=example_df1, 
                                   labels=['pos', 'neg'])

# %%
example_dataset1_dataset.profile_dataset()
# Out:
# array([<AxesSubplot:title={'center':'Class Conditional Densities'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Label Density'}>,
#        <AxesSubplot:title={'center':'Joint Density'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Classifier Score Density'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Calibration Curve'}, xlabel='$C(x)$', ylabel='$P(y=1|C(x))$'>],
#       dtype=object)

# %%
example_dataset1_dataset.update_calibration_curve(method='platt scaling')

# %%
example_dataset1_dataset.profile_dataset()
# Out:
# array([<AxesSubplot:title={'center':'Class Conditional Densities'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Label Density'}>,
#        <AxesSubplot:title={'center':'Joint Density'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Classifier Score Density'}, xlabel='score', ylabel='density'>,
#        <AxesSubplot:title={'center':'Calibration Curve'}, xlabel='$C(x)$', ylabel='$P(y=1|C(x))$'>],
#       dtype=object)
