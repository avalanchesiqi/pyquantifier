# %%
import sys
from os.path import dirname, abspath

sys.path.append(dirname(abspath('')))

# %%
import pandas as pd

df = pd.read_csv('data/example_data1.csv')

# %%
df.head()
# Out:
#        C(X)   GT
# 0  0.368554  pos
# 1  0.900048  pos
# 2  0.742137  pos
# 3  0.754380  pos
# 4  0.965738  pos

# %%
from pyquantifier.distribution.joint_density import EmpiricalJointDistribution

# %%
# convert df to a list of tuples
data = [tuple(x) for x in df.values]

# %%
empirical_joint_distribution = EmpiricalJointDistribution(data)

empirical_joint_distribution.visualize_all_distribution()
